# %% [markdown]
# # Elections

# %%
from power_indices import calculate_indices

# %% [markdown]
# ## Thuringia 24

# %%
seats = {
    'Linke': 12, 
    'AfD': 32, 
    'CDU': 23, 
    'SPD': 6, 
    'BSW': 15
}
calculate_indices(seats)

# %% [markdown]
# ## Saxony 24

# %%
seats = {
    'CDU': 41,
    'AfD': 40, 
    'Linke': 6, 
    'Grüne': 7, 
    'SPD': 10, 
    'FW': 1, 
    'BSW': 15
}
calculate_indices(seats)

# %% [markdown]
# ## Brandenburg 24

# %%
seats = {
    "SPD": 32,
    "AfD": 30,
    "CDU":12,
    "BSW": 14
}
calculate_indices(seats)

# %% [markdown]
# ## France 24

# %%
seats = {
    'NFP': 180,
    'Gauche': 12,
    'Ensemble': 163,
    'Les Républicains': 66,
    'RN': 143,
    'Divers droite': 15,
    'Régionaliste': 10,
    'Autres': 3
}
calculate_indices(seats)

# %% [markdown]
# ## EU 24

# %%
seats = {
    'The Left': 46,
    'S&D': 136,
    'EFA': 53,
    'Renew Europe': 77,
    'EVP': 188,
    'EKR': 78,
    'PfE': 84,
    'ESN': 25,
    'NI': 33
}
calculate_indices(seats)
